# %% [markdown]
# # All about DataFrames Pandas objects

# %% [markdown]
# - Read the dataset 'fandango_score_comparison' in the fandango dataframe.
# - Return a dataframe containing only the first and last lines and assign the result to the first_last variable.
# - Display the result.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
# %matplotlib inline
# standard import statement for seaborn
import seaborn as sns

# %%
fandango = pd.read_csv('fandango_score_comparison.csv')

# %%
top = fandango.head(1)
bottom = fandango.tail(1)
first_last = pd.concat([top,bottom])
first_last
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0       3.70          4.30  ...       3.90            3.5                 4.5
# 145     4.35          3.15  ...       3.35            4.5                 3.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                      3.5                         3.5              4.0
# 145                    3.5                         3.0              3.5
#
# ...

# %% [markdown]
# ## Use custom indexes

# %%
fandango["FILM"]
# Out:
# 0                 Avengers: Age of Ultron (2015)
# 1                              Cinderella (2015)
# 2                                 Ant-Man (2015)
# 3                         Do You Believe? (2015)
# 4                  Hot Tub Time Machine 2 (2015)
#                          ...
# 141                            Mr. Holmes (2015)
# 142                                   '71 (2015)
# 143                   Two Days, One Night (2014)
# 144    Gett: The Trial of Viviane Amsalem (2015)
# 145           Kumiko, The Treasure Hunter (2015)
# Name: FILM, Length: 146, dtype: object

# %% [markdown]
# - Use the set_index method to index our fandango DataFrame with the 'FILM' column. Note that we want to keep the 'FILM' column. Furthermore we want to keep the original DataFrame and create a new one that we will assign to the fandango_films variable.
# - Display the index of the DataFrame fandango_films in the iade of the index attribute.

# %%
fandango_films = fandango.set_index("FILM", drop = False) 
print(fandango_films.index)
# Out:
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %%
fandango_films
# Out:
#                                                                                 FILM  \
# FILM
# Avengers: Age of Ultron (2015)                        Avengers: Age of Ultron (2015)
# Cinderella (2015)                                                  Cinderella (2015)
# Ant-Man (2015)                                                        Ant-Man (2015)
# Do You Believe? (2015)                                        Do You Believe? (2015)
# Hot Tub Time Machine 2 (2015)                          Hot Tub Time Machine 2 (2015)
# ...                                                                              ...
# Mr. Holmes (2015)                                                  Mr. Holmes (2015)
# '71 (2015)                                                                '71 (2015)
# Two Days, One Night (2014)                                Two Days, One Night (2014)
# Gett: The Trial of Viviane Amsalem (2015)  Gett: The Trial of Viviane Amsalem (2015)
# ...

# %% [markdown]
# ## Selecting values from an index

# %% [markdown]
# - Select the following movies from the DataFrame fandango_films (in the following order) and assign them to the some_movies variable:
# >- "Top Five (2014)"
# >- "Black Sea (2015)"
# >- "Taken 3 (2015)"
# - Display the result.

# %%
fandango_films.loc["Avengers: Age of Ultron (2015)"]
# Out:
# FILM                          Avengers: Age of Ultron (2015)
# RottenTomatoes                                            74
# RottenTomatoes_User                                       86
# Metacritic                                                66
# Metacritic_User                                          7.1
# IMDB                                                     7.8
# Fandango_Stars                                             5
# Fandango_Ratingvalue                                     4.5
# RT_norm                                                  3.7
# RT_user_norm                                             4.3
# Metacritic_norm                                          3.3
# Metacritic_user_nom                                     3.55
# IMDB_norm                                                3.9
# RT_norm_round                                            3.5
# RT_user_norm_round                                       4.5
# ...

# %% [markdown]
# ## Apply() method on the columns of a DataFrame

# %% [markdown]
# - Get the float_df dataframe I made as an example (which returns the float64 decimal columns)
# - Use the apply() method on this float_df dataframe to halve each value and assign the result to the exo_df variable.
# - Display the first lines of the result.

# %%
types = fandango_films.dtypes
float_column = types[types.values== 'float64'].index
float_df = fandango_films[float_column]

# %%
exo_df = float_df.apply(lambda x : x/2)
print(exo_df.head(1))
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             3.55   3.9             2.5
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                  2.25     1.85          2.15
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# FILM
# Avengers: Age of Ultron (2015)             1.65                1.775
#
#                                 IMDB_norm  RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)       1.95           1.75                2.25
#
#                                 Metacritic_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                   1.75
#
#                                 Metacritic_user_norm_round  IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                        1.75              2.0
#
#                                 Fandango_Difference
# ...

# %% [markdown]
# ## Apply() method on the lines of a DataFrame

# %% [markdown]
# - Use the apply() method to calculate the average (mean() method from the Numpy library) of the values of each movie for 'RT_user_norm' and 'metacritic_user_name' and then assign the result to the variable rt_mt_means.
# - Display the first 5 values of rt_mt_means.

# %%
rt = float_df[['RT_user_norm','Metacritic_norm_round']]

# %%
rt_means = rt.apply(lambda x : np.mean(x),axis = 1)

# %%
rt_means
# Out:
# FILM
# Avengers: Age of Ultron (2015)               3.900
# Cinderella (2015)                            3.750
# Ant-Man (2015)                               3.750
# Do You Believe? (2015)                       2.600
# Hot Tub Time Machine 2 (2015)                1.450
#                                              ...
# Mr. Holmes (2015)                            3.700
# '71 (2015)                                   4.050
# Two Days, One Night (2014)                   4.200
# Gett: The Trial of Viviane Amsalem (2015)    4.275
# Kumiko, The Treasure Hunter (2015)           3.325
# Length: 146, dtype: float64

# %%
rt
# Out:
#                                            RT_user_norm  Metacritic_norm_round
# FILM
# Avengers: Age of Ultron (2015)                     4.30                    3.5
# Cinderella (2015)                                  4.00                    3.5
# Ant-Man (2015)                                     4.50                    3.0
# Do You Believe? (2015)                             4.20                    1.0
# Hot Tub Time Machine 2 (2015)                      1.40                    1.5
# ...                                                 ...                    ...
# Mr. Holmes (2015)                                  3.90                    3.5
# '71 (2015)                                         4.10                    4.0
# Two Days, One Night (2014)                         3.90                    4.5
# Gett: The Trial of Viviane Amsalem (2015)          4.05                    4.5
# Kumiko, The Treasure Hunter (2015)                 3.15                    3.5
#
# ...
